# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnukhokhar/100DaysofMLCode/blob/master/Copy_of_final_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df1 = pd.read_csv("data.csv" )

# %%
df1.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
import seaborn as sns
sns.countplot(y=df1.iloc[:,12],data=df1)
# Out:
# <AxesSubplot:xlabel='count', ylabel='DEATH_EVENT'>

# %%
df1.describe().transpose()
# Out:
#                           count           mean           std      min  \
# age                       299.0      60.833893     11.894809     40.0
# anaemia                   299.0       0.431438      0.496107      0.0
# creatinine_phosphokinase  299.0     581.839465    970.287881     23.0
# diabetes                  299.0       0.418060      0.494067      0.0
# ejection_fraction         299.0      38.083612     11.834841     14.0
# high_blood_pressure       299.0       0.351171      0.478136      0.0
# platelets                 299.0  263358.029264  97804.236869  25100.0
# serum_creatinine          299.0       1.393880      1.034510      0.5
# serum_sodium              299.0     136.625418      4.412477    113.0
# sex                       299.0       0.648829      0.478136      0.0
# smoking                   299.0       0.321070      0.467670      0.0
# time                      299.0     130.260870     77.614208      4.0
# DEATH_EVENT               299.0       0.321070      0.467670      0.0
#
#                                25%       50%       75%       max
# age                           51.0      60.0      70.0      95.0
# anaemia                        0.0       0.0       1.0       1.0
# creatinine_phosphokinase     116.5     250.0     582.0    7861.0
# diabetes                       0.0       0.0       1.0       1.0
# ejection_fraction             30.0      38.0      45.0      80.0
# high_blood_pressure            0.0       0.0       1.0       1.0
# platelets                 212500.0  262000.0  303500.0  850000.0
# serum_creatinine               0.9       1.1       1.4       9.4
# serum_sodium                 134.0     137.0     140.0     148.0
# sex                            0.0       1.0       1.0       1.0
# smoking                        0.0       0.0       1.0       1.0
# time                          73.0     115.0     203.0     285.0
# DEATH_EVENT                    0.0       0.0       1.0       1.0

# %%
df1.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
df1.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
# %matplotlib inline

# %% [markdown]
# ###  **FOR PLOTTING HISTOGRAM**

# %%
import matplotlib.pyplot as plt
df1.hist(bins=50, figsize=(20, 15))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'anaemia'}>,
#         <AxesSubplot:title={'center':'creatinine_phosphokinase'}>,
#         <AxesSubplot:title={'center':'diabetes'}>],
#        [<AxesSubplot:title={'center':'ejection_fraction'}>,
#         <AxesSubplot:title={'center':'high_blood_pressure'}>,
#         <AxesSubplot:title={'center':'platelets'}>,
#         <AxesSubplot:title={'center':'serum_creatinine'}>],
#        [<AxesSubplot:title={'center':'serum_sodium'}>,
#         <AxesSubplot:title={'center':'sex'}>,
#         <AxesSubplot:title={'center':'smoking'}>,
#         <AxesSubplot:title={'center':'time'}>],
#        [<AxesSubplot:title={'center':'DEATH_EVENT'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df1.plot(kind = 'density', subplots= True, layout = (4,4), sharex =False, figsize = (12, 12));

# %%
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(df1.corr())
# Out:
# <AxesSubplot:>

# %%
df = df1.drop(columns='time', axis=1)
print();
print(df1.head())
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
sns.countplot(x='DEATH_EVENT',hue='sex',data=df)
# Out:
# <AxesSubplot:xlabel='DEATH_EVENT', ylabel='count'>

# %% [markdown]
# ### **TRAINING AND TESTING DATA SPLIT**

# %%
import numpy as np
def split_train_test(data, test_ratio):
    np.random.seed(42)
    shuffled = np.random.permutation(len(data))
    print(shuffled)
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:] 
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train_set, test_set = split_train_test(df, 0.2)
# Out:
# [281 265 164   9  77 278  93 109   5 173  97 195 184 154  57  60 147 108
#   63 140 155 104 247  46  42 275 280 116 213 236  17 239  33  24  45   7
#  113 194 111  92  75  82 118  76 129 197 210 288 219 178 144 186  84 248
#  277  73 244  25 209  59   6 183 185 146  30  22 254  56 237 285 126 228
#  283 255 158 225  78  66 296 192 181  19 170  79  90 132  72  15  10 157
#  224  68 222  37  16 119 268 269  67 101  69  31 172 148 223 114  18 179
#   96 165 291  86 246 143 231 124 139 152 204  55 232 182 180 137 251  38
#  125 193 167 203 112 264 117 282 273 221 176   2 115 177 175 120 208 259
#  127  74  29  83 261 107 287 245 250 294 230  65 196  85 211 159  12  35
#   28 142 229 279 168  51  95 206 218  41  89 215 136  26 292 141 198   0
#  267 271 100 258 253 171  98  36  61 150 234 200 240  11 295 266  27 242
#    4 122  32 202 162 226 256 138  62 135 128 289   8  70 263  64  44 233
#  156  40 123 274 216 153  23 260 110  81 207 212  39 238 290 284 199  14
#   47  94 262 227 272 201 161  43 217 145 190 220 249   3 105  53 133   1
#  131 103  49 163  80 205  34  91  52 241  13  88 166 293 134 286 243  54
#   50 174 189 297 187 169  58  48 235 252  21 160 276 191 257 149 130 151
#   99  87 214 121 298  20 188  71 106 270 102]

# %%
print(f"Rows in train set: {len(train_set)}\nRows in test set: {len(test_set)}\n")
# Out:
# Rows in train set: 240
# Rows in test set: 59

# %%
from sklearn.model_selection import train_test_split
train_set, test_set  = train_test_split(df, test_size=0.2, random_state=42)
print(f"Rows in train set: {len(train_set)}\nRows in test set: {len(test_set)}\n")
# Out:
# Rows in train set: 239
# Rows in test set: 60

# %%
X = df.drop(columns='DEATH_EVENT', axis=1)
Y = df['DEATH_EVENT']

# %%
print(Y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 294    0
# 295    0
# 296    0
# 297    0
# 298    0
# Name: DEATH_EVENT, Length: 299, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (299, 11) (239, 11) (60, 11)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
accuracy_list = []


model.fit(X_train, Y_train)
log_reg_pred = model.predict(X_test)
log_reg_acc = accuracy_score(Y_test, log_reg_pred)
accuracy_list.append(100*log_reg_acc)
# Out:
# Accuracy on Training data :  0.7698744769874477

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\python310\lib\site-packages (0.21.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\python310\lib\site-packages (from mlxtend) (3.5.1)
# Requirement already satisfied: joblib>=0.13.2 in c:\python310\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\python310\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\python310\lib\site-packages (from mlxtend) (1.0.2)
# Requirement already satisfied: scipy>=1.2.1 in c:\python310\lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: numpy>=1.16.2 in c:\python310\lib\site-packages (from mlxtend) (1.22.2)
# Requirement already satisfied: setuptools in c:\python310\lib\site-packages (from mlxtend) (58.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.33.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.8)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python310\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import classification_report,confusion_matrix

print(confusion_matrix(Y_test,log_reg_pred))
print(classification_report(Y_test,log_reg_pred))
print("Accuracy of Logistic Regression is : ", "{:.2f}%".format(100* log_reg_acc))
# Out:
# [[38  3]
#  [15  4]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.93      0.81        41
#            1       0.57      0.21      0.31        19
#
#     accuracy                           0.70        60
#    macro avg       0.64      0.57      0.56        60
# weighted avg       0.67      0.70      0.65        60
#
# Accuracy of Logistic Regression is :  70.00%

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

from sklearn import metrics

log_reg_y_pred = model.predict(X_test)
log_reg_cm = metrics.confusion_matrix(log_reg_y_pred, Y_test)
sns.heatmap(log_reg_cm, annot=True, fmt='.2f',
xticklabels = ["Heart Not Failed","Heart Fail"] ,
yticklabels = ["Heart Not Failed","Heart Fail"] )
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('Logistic Regression')
# Out:
# Text(0.5, 1.0, 'Logistic Regression')

# %%
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  0.7

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(X_train, Y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(Y_test, y_pred))
print(classification_report(Y_test, y_pred))


log_reg_cm = metrics.confusion_matrix(y_pred, Y_test)
sns.heatmap(log_reg_cm, annot=True, fmt='.2f',
xticklabels = ["Heart Not Failed","Heart Fail"] ,
yticklabels = ["Heart Not Failed","Heart Fail"] )
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('Logistic Regression')
# Out:
# [[30 11]
#  [13  6]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.73      0.71        41
#            1       0.35      0.32      0.33        19
#
#     accuracy                           0.60        60
#    macro avg       0.53      0.52      0.52        60
# weighted avg       0.59      0.60      0.59        60
# Text(0.5, 1.0, 'Logistic Regression')

# %%
training_accuracy = accuracy_score(y_pred, Y_test)
print('Accuracy on Training data : ', training_accuracy)
# Out:
# Accuracy on Training data :  0.6

# %%
Specificity = log_reg_cm[0,0]/(log_reg_cm[0,0]+log_reg_cm[0,1])
print( Specificity)
# Out:
# 0.6976744186046512

# %%
Sensitivity = log_reg_cm[1,1]/(log_reg_cm[1,0]+log_reg_cm[1,1])
print(Sensitivity)
# Out:
# 0.35294117647058826

# %%
 sns.set_style('darkgrid')
 preds_train = model.predict(X_train)
 # calculate prediction probability
 prob_train = np.squeeze(model.predict_proba(X_train)[:,1].reshape(1,-1))
 prob_test = np.squeeze(model.predict_proba(X_test)[:,1].reshape(1,-1))
 # false positive rate, true positive rate, thresholds
 fpr1, tpr1, thresholds1 = metrics.roc_curve(Y_test, prob_test)
 fpr2, tpr2, thresholds2 = metrics.roc_curve(Y_train, prob_train)
 auc1 = metrics.auc(fpr1, tpr1)
 # auc score
 auc2 = metrics.auc(fpr2, tpr2)
 plt.figure(figsize=(8,8))
 # plot auc 
 plt.plot(fpr1, tpr1, color='blue', label='Test ROC curve area = %0.2f'%auc1)
 plt.plot(fpr2, tpr2, color='green', label='Train ROC curve area = %0.2f'%auc2)
 plt.plot([0,1],[0,1], 'r--')
 plt.xlim([-0.1, 1.1])
 plt.ylim([-0.1, 1.1])
 plt.xlabel('False Positive Rate', size=14)
 plt.ylabel('True Positive Rate', size=14)
 plt.legend(loc='lower right')
 plt.show()

# %%
error=1-training_accuracy
print("Error is ",end=" ")
print(error)
# Out:
# Error is  0.4

# %%
tn, fp, fn, tp = confusion_matrix(list(y_pred), list(Y_test), labels=[0, 1]).ravel()
print('True Positive', tp)

print('False Positive', fp)
# Out:
# True Positive 6
# False Positive 13

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
  
knn = KNeighborsClassifier(n_neighbors=7)
  
knn.fit(X_train, Y_train)

y_pred = knn.predict(X_test)
# Calculate the accuracy of the model
print("Accuracy of KNN Model is ",knn.score(X_test, Y_test))
# Out:
# Accuracy of KNN Model is  0.6333333333333333

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, y_pred))

from sklearn.metrics import accuracy_score
acc=accuracy_score(Y_test, y_pred)
error=1-acc
print("Error is ",end=" ")
print(error)

from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(Y_test, y_pred).ravel()
specificity = tn / (tn+fp)
sensitivity=tp/(tp+fn)
print("Sensitivity is ",end=" ")
print(sensitivity)

print ("specificity is ",end=" ")
print(specificity)


from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(Y_test, y_pred)
print("AUC score is ",end=" ")
print(auc_score1)

from sklearn import metrics
fpr, tpr, thresh = metrics.roc_curve(Y_test,y_pred)
auc=metrics.auc(fpr, tpr)
plt.plot(fpr, tpr, label='ROC curve (area = %.4f)' %auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r', label='Random guess')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid()
plt.legend()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.83      0.76        41
#            1       0.36      0.21      0.27        19
#
#     accuracy                           0.63        60
#    macro avg       0.53      0.52      0.51        60
# weighted avg       0.59      0.63      0.60        60
#
# Error is  0.3666666666666667
# Sensitivity is  0.21052631578947367
# specificity is  0.8292682926829268
# AUC score is  0.5198973042362002

# %%
tn, fp, fn, tp = confusion_matrix(list(y_pred), list(Y_test), labels=[0, 1]).ravel()
print('True Positive', tp)

print('False Positive', fp)



from sklearn import metrics

knn_y_pred = model.predict(X_test)
knn_cm = metrics.confusion_matrix(knn_y_pred, Y_test)
sns.heatmap(log_reg_cm, annot=True, fmt='.2f',
xticklabels = ["Heart Not Failed","Heart Fail"] ,
yticklabels = ["Heart Not Failed","Heart Fail"] )
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('KNN')
# Out:
# True Positive 9
# False Positive 10
# Text(0.5, 1.0, 'KNN')

# %%
from sklearn.svm import SVC  
clf = SVC(kernel='linear') 
a = np.array(df1)
y  = a[:,12]
  
# fitting x samples and y classes 
clf.fit(df1, y)
# Out:
# SVC(kernel='linear')

# %%
from sklearn import svm
from sklearn.svm import SVC

classifier = svm.SVC(kernel ='linear', C = 1).fit(X, y)
classifier.fit(X_train, Y_train)
y_pred = classifier.predict(X_test)

print(accuracy_score(Y_test, y_pred))
# Out:
# 0.7166666666666667

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, y_pred))

from sklearn.metrics import accuracy_score
acc=accuracy_score(Y_test, y_pred)
error=1-acc
print("Error is ",end=" ")
print(error)

from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(Y_test, y_pred).ravel()
specificity = tn / (tn+fp)
sensitivity=tp/(tp+fn)
print("Sensitivity is ",end=" ")
print(sensitivity)

print ("specificity is ",end=" ")
print(specificity)


from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(Y_test, y_pred)
print("AUC score is ",end=" ")
print(auc_score1)

from sklearn import metrics
fpr, tpr, thresh = metrics.roc_curve(Y_test,y_pred)
auc=metrics.auc(fpr, tpr)
plt.plot(fpr, tpr, label='ROC curve (area = %.4f)' %auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r', label='Random guess')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid()
plt.legend()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.98      0.82        41
#            1       0.75      0.16      0.26        19
#
#     accuracy                           0.72        60
#    macro avg       0.73      0.57      0.54        60
# weighted avg       0.73      0.72      0.65        60
#
# Error is  0.2833333333333333
# Sensitivity is  0.15789473684210525
# specificity is  0.975609756097561
# AUC score is  0.5667522464698331

# %%
tn, fp, fn, tp = confusion_matrix(list(y_pred), list(Y_test), labels=[0, 1]).ravel()
print('True Positive', tp)

print('False Positive', fp)

from sklearn import metrics

lsvm_y_pred = model.predict(X_test)
lSvm_cm = metrics.confusion_matrix(lsvm_y_pred, Y_test)
sns.heatmap(log_reg_cm, annot=True, fmt='.2f',
xticklabels = ["Heart Not Failed","Heart Fail"] ,
yticklabels = ["Heart Not Failed","Heart Fail"] )
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('Linear SVM')
# Out:
# True Positive 10
# False Positive 9
# Text(0.5, 1.0, 'Linear SVM')

# %%
#RBF SVM
from sklearn.svm import SVC
svm = SVC(kernel='rbf', random_state=1, gamma=0.1, C=0.02)
svm.fit(X_train, Y_train)
y_pred = svm.predict(X_test)

print("Accuracy: ",accuracy_score(Y_test, y_pred))
# Out:
# Accuracy:  0.6833333333333333

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, y_pred))

from sklearn.metrics import accuracy_score
acc=accuracy_score(Y_test, y_pred)
error=1-acc
print("Error is ",end=" ")
print(error)

from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(Y_test, y_pred).ravel()
specificity = tn / (tn+fp)
sensitivity=tp/(tp+fn)
print("Sensitivity is ",end=" ")
print(sensitivity)

print ("specificity is ",end=" ")
print(specificity)


from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(Y_test, y_pred)
print("AUC score is ",end=" ")
print(auc_score1)

from sklearn import metrics
fpr, tpr, thresh = metrics.roc_curve(Y_test,y_pred)
auc=metrics.auc(fpr, tpr)
plt.plot(fpr, tpr, label='ROC curve (area = %.4f)' %auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r', label='Random guess')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid()
plt.legend()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      1.00      0.81        41
#            1       0.00      0.00      0.00        19
#
#     accuracy                           0.68        60
#    macro avg       0.34      0.50      0.41        60
# weighted avg       0.47      0.68      0.55        60
#
# Error is  0.31666666666666665
# Sensitivity is  0.0
# specificity is  1.0
# AUC score is  0.5
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
tn, fp, fn, tp = confusion_matrix(list(y_pred), list(Y_test), labels=[0, 1]).ravel()
print('True Positive', tp)

print('False Positive', fp)


from sklearn import metrics

rsvm_y_pred = model.predict(X_test)
rsvm_cm = metrics.confusion_matrix(rsvm_y_pred, Y_test)
sns.heatmap(log_reg_cm, annot=True, fmt='.2f',
xticklabels = ["Heart Not Failed","Heart Fail"] ,
yticklabels = ["Heart Not Failed","Heart Fail"] )
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('RBF SVM')
# Out:
# True Positive 10
# False Positive 9
# Text(0.5, 1.0, 'RBF SVM')

# %%
#NAIVE BAYES
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
gnb = GaussianNB()
y_pred = gnb.fit(X_train, Y_train).predict(X_test)
accuracy=accuracy_score(Y_test,y_pred)
print("Accuracy of Naive Bayes algorithm is ",accuracy)
# Out:
# Accuracy of Naive Bayes algorithm is  0.7

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, y_pred))

from sklearn.metrics import accuracy_score
acc=accuracy_score(Y_test, y_pred)
error=1-acc
print("Error is ",end=" ")
print(error)

from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(Y_test, y_pred).ravel()
specificity = tn / (tn+fp)
sensitivity=tp/(tp+fn)
print("Sensitivity is ",end=" ")
print(sensitivity)

print ("specificity is ",end=" ")
print(specificity)


from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(Y_test, y_pred)
print("AUC score is ",end=" ")
print(auc_score1)

from sklearn import metrics
fpr, tpr, thresh = metrics.roc_curve(Y_test,y_pred)
auc=metrics.auc(fpr, tpr)
plt.plot(fpr, tpr, label='ROC curve (area = %.4f)' %auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r', label='Random guess')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid()
plt.legend()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.95      0.81        41
#            1       0.60      0.16      0.25        19
#
#     accuracy                           0.70        60
#    macro avg       0.65      0.55      0.53        60
# weighted avg       0.67      0.70      0.63        60
#
# Error is  0.30000000000000004
# Sensitivity is  0.15789473684210525
# specificity is  0.9512195121951219
# AUC score is  0.5545571245186136

# %%
tn, fp, fn, tp = confusion_matrix(list(y_pred), list(Y_test), labels=[0, 1]).ravel()
print('True Positive', tp)

print('False Positive', fp)


from sklearn import metrics

nb_y_pred = model.predict(X_test)
nb_cm = metrics.confusion_matrix(log_reg_y_pred, Y_test)
sns.heatmap(nb_cm, annot=True, fmt='.2f',
xticklabels = ["Heart Not Failed","Heart Fail"] ,
yticklabels = ["Heart Not Failed","Heart Fail"] )
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('Naive Bayes')
# Out:
# True Positive 9
# False Positive 10
# Text(0.5, 1.0, 'Naive Bayes')

# %%
#DECISION TREE
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
 
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,Y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
print("Accuracy:",accuracy_score(Y_test, y_pred))
# Out:
# Accuracy: 0.65

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, y_pred))

from sklearn.metrics import accuracy_score
acc=accuracy_score(Y_test, y_pred)
error=1-acc
print("Error is ",end=" ")
print(error)

from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(Y_test, y_pred).ravel()
specificity = tn / (tn+fp)
sensitivity=tp/(tp+fn)
print("Sensitivity is ",end=" ")
print(sensitivity)

print ("specificity is ",end=" ")
print(specificity)


from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(Y_test, y_pred)
print("AUC score is ",end=" ")
print(auc_score1)

from sklearn import metrics
fpr, tpr, thresh = metrics.roc_curve(Y_test,y_pred)
auc=metrics.auc(fpr, tpr)
plt.plot(fpr, tpr, label='ROC curve (area = %.4f)' %auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r', label='Random guess')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid()
plt.legend()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.71      0.73        41
#            1       0.45      0.53      0.49        19
#
#     accuracy                           0.65        60
#    macro avg       0.61      0.62      0.61        60
# weighted avg       0.67      0.65      0.66        60
#
# Error is  0.35
# Sensitivity is  0.5263157894736842
# specificity is  0.7073170731707317
# AUC score is  0.6168164313222079

# %%
tn, fp, fn, tp = confusion_matrix(list(y_pred), list(Y_test), labels=[0, 1]).ravel()
print('True Positive', tp)

print('False Positive', fp)

from sklearn import metrics

dt_y_pred = model.predict(X_test)
dt_cm = metrics.confusion_matrix(log_reg_y_pred, Y_test)
sns.heatmap(log_reg_cm, annot=True, fmt='.2f',
xticklabels = ["Heart Not Failed","Heart Fail"] ,
yticklabels = ["Heart Not Failed","Heart Fail"] )
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('Decision Tree')
# Out:
# True Positive 10
# False Positive 9
# Text(0.5, 1.0, 'Decision Tree')

# %%
#RANDOM FOREST
from sklearn.ensemble import RandomForestClassifier
# creating a RF classifier
clf = RandomForestClassifier(n_estimators = 100) 
 
# Training the model on the training dataset
# fit function is used to train the model using the training sets as parameters
clf.fit(X_train, Y_train)
 
# performing predictions on the test dataset
y_pred = clf.predict(X_test)
print("Accuracy:",accuracy_score(Y_test, y_pred))
# Out:
# Accuracy: 0.75

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, y_pred))

from sklearn.metrics import accuracy_score
acc=accuracy_score(Y_test, y_pred)
error=1-acc
print("Error is ",end=" ")
print(error)

from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(Y_test, y_pred).ravel()
specificity = tn / (tn+fp)
sensitivity=tp/(tp+fn)
print("Sensitivity is ",end=" ")
print(sensitivity)

print ("specificity is ",end=" ")
print(specificity)


from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(Y_test, y_pred)
print("AUC score is ",end=" ")
print(auc_score1)

from sklearn import metrics
fpr, tpr, thresh = metrics.roc_curve(Y_test,y_pred)
auc=metrics.auc(fpr, tpr)
plt.plot(fpr, tpr, label='ROC curve (area = %.4f)' %auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r', label='Random guess')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid()
plt.legend()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83        41
#            1       0.64      0.47      0.55        19
#
#     accuracy                           0.75        60
#    macro avg       0.71      0.68      0.69        60
# weighted avg       0.74      0.75      0.74        60
#
# Error is  0.25
# Sensitivity is  0.47368421052631576
# specificity is  0.8780487804878049
# AUC score is  0.6758664955070603

# %%
tn, fp, fn, tp = confusion_matrix(list(y_pred), list(Y_test), labels=[0, 1]).ravel()
print('True Positive', tp)

print('False Positive', fp)

from sklearn import metrics

rf_y_pred = model.predict(X_test)
rf_cm = metrics.confusion_matrix(rf_y_pred, Y_test)
sns.heatmap(log_reg_cm, annot=True, fmt='.2f',
xticklabels = ["Heart Not Failed","Heart Fail"] ,
yticklabels = ["Heart Not Failed","Heart Fail"] )
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('Random Forest')
# Out:
# True Positive 9
# False Positive 10
# Text(0.5, 1.0, 'Random Forest')

# %%
#Ada Boost
from sklearn.ensemble import AdaBoostClassifier
adb = AdaBoostClassifier()
adb_model = adb.fit(X_train,Y_train)
y_pred = adb_model.predict(X_test)
print("Accuracy:",accuracy_score(Y_test, y_pred))
# Out:
# Accuracy: 0.7666666666666667

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, y_pred))

from sklearn.metrics import accuracy_score
acc=accuracy_score(Y_test, y_pred)
error=1-acc
print("Error is ",end=" ")
print(error)

from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(Y_test, y_pred).ravel()
specificity = tn / (tn+fp)
sensitivity=tp/(tp+fn)
print("Sensitivity is ",end=" ")
print(sensitivity)

print ("specificity is ",end=" ")
print(specificity)


from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(Y_test, y_pred)
print("AUC score is ",end=" ")
print(auc_score1)

from sklearn import metrics
fpr, tpr, thresh = metrics.roc_curve(Y_test,y_pred)
auc=metrics.auc(fpr, tpr)
plt.plot(fpr, tpr, label='ROC curve (area = %.4f)' %auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r', label='Random guess')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid()
plt.legend()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84        41
#            1       0.67      0.53      0.59        19
#
#     accuracy                           0.77        60
#    macro avg       0.73      0.70      0.71        60
# weighted avg       0.76      0.77      0.76        60
#
# Error is  0.23333333333333328
# Sensitivity is  0.5263157894736842
# specificity is  0.8780487804878049
# AUC score is  0.7021822849807445

# %%
tn, fp, fn, tp = confusion_matrix(list(y_pred), list(Y_test), labels=[0, 1]).ravel()
print('True Positive', tp)

print('False Positive', fp)

from sklearn import metrics

ab_y_pred = model.predict(X_test)
ab_cm = metrics.confusion_matrix(ab_y_pred, Y_test)
sns.heatmap(log_reg_cm, annot=True, fmt='.2f',
xticklabels = ["Heart Not Failed","Heart Fail"] ,
yticklabels = ["Heart Not Failed","Heart Fail"] )
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('ADA Boost')
# Out:
# True Positive 9
# False Positive 10
# Text(0.5, 1.0, 'ADA Boost')

# %%
# MLP Classifier
from sklearn.neural_network import MLPClassifier

#Initializing the MLPClassifier
classifier = MLPClassifier(hidden_layer_sizes=(150,100,50), max_iter=300,activation = 'relu',solver='adam',random_state=1)
classifier.fit(X_train, Y_train)
y_pred = classifier.predict(X_test)
print("Accuracy:",accuracy_score(Y_test, y_pred))
# Out:
# Accuracy: 0.6833333333333333

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, y_pred))

from sklearn.metrics import accuracy_score
acc=accuracy_score(Y_test, y_pred)
error=1-acc
print("Error is ",end=" ")
print(error)

from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(Y_test, y_pred).ravel()
specificity = tn / (tn+fp)
sensitivity=tp/(tp+fn)
print("Sensitivity is ",end=" ")
print(sensitivity)

print ("specificity is ",end=" ")
print(specificity)


from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(Y_test, y_pred)
print("AUC score is ",end=" ")
print(auc_score1)

from sklearn import metrics
fpr, tpr, thresh = metrics.roc_curve(Y_test,y_pred)
auc=metrics.auc(fpr, tpr)
plt.plot(fpr, tpr, label='ROC curve (area = %.4f)' %auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r', label='Random guess')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid()
plt.legend()
plt.show()
# Out:
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.68      1.00      0.81        41
#            1       0.00      0.00      0.00        19
#
#     accuracy                           0.68        60
#    macro avg       0.34      0.50      0.41        60
# weighted avg       0.47      0.68      0.55        60
#
# Error is  0.31666666666666665
# Sensitivity is  0.0
# specificity is  1.0
# AUC score is  0.5

# %%
tn, fp, fn, tp = confusion_matrix(list(y_pred), list(Y_test), labels=[0, 1]).ravel()
print('True Positive', tp)

print('False Positive', fp)

from sklearn import metrics

mlp_y_pred = model.predict(X_test)
mlp_cm = metrics.confusion_matrix(mlp_y_pred, Y_test)
sns.heatmap(log_reg_cm, annot=True, fmt='.2f',
xticklabels = ["Heart Not Failed","Heart Fail"] ,
yticklabels = ["Heart Not Failed","Heart Fail"] )
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('MLP Classifier')
# Out:
# True Positive 0
# False Positive 19
# Text(0.5, 1.0, 'MLP Classifier')

# %%
#Quadratic Discriminant Analysis

from sklearn.model_selection import train_test_split
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis 
from sklearn import datasets
from sklearn import metrics
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


model = QuadraticDiscriminantAnalysis()
model.fit(X_train, Y_train)
 

expected_y  = Y_test
predicted_y = model.predict(X_test)
print(metrics.classification_report(expected_y, predicted_y))
print(sns.heatmap(metrics.confusion_matrix(expected_y, predicted_y),annot=True))
print("Accuracy:",accuracy_score(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.88      0.78        41
#            1       0.44      0.21      0.29        19
#
#     accuracy                           0.67        60
#    macro avg       0.58      0.54      0.53        60
# weighted avg       0.62      0.67      0.63        60
#
# AxesSubplot(0.125,0.125;0.62x0.755)
# Accuracy: 0.6833333333333333

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(Y_test, predicted_y)
error=1-acc
print("Error is ",end=" ")
print(error)

from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(Y_test,predicted_y).ravel()
specificity = tn / (tn+fp)
sensitivity=tp/(tp+fn)
print("Sensitivity is ",end=" ")
print(sensitivity)

print ("specificity is ",end=" ")
print(specificity)
from sklearn import metrics
fpr, tpr, thresh = metrics.roc_curve(Y_test,predicted_y)
auc=metrics.auc(fpr, tpr)
plt.plot(fpr, tpr, label='ROC curve (area = %.4f)' %auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r', label='Random guess')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid()
plt.legend()
plt.show()
# Out:
# Error is  0.33333333333333337
# Sensitivity is  0.21052631578947367
# specificity is  0.8780487804878049

# %%
#Gradient Boosting Classifier

import pandas as pd
import numpy as np
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingClassifier
gradient_booster = GradientBoostingClassifier(learning_rate=0.1)
gradient_booster.get_params()
gradient_booster.fit(X_train,Y_train)
y_predict = gradient_booster.predict(X_test)
print(metrics.classification_report(Y_test,y_predict))
print(sns.heatmap(metrics.confusion_matrix(Y_test,y_predict),annot=True))

from sklearn.metrics import accuracy_score
acc=accuracy_score(Y_test, y_predict)
error=1-acc
print("Error is ",end=" ")
print(error)

from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(Y_test, y_predict).ravel()
specificity = tn / (tn+fp)
sensitivity=tp/(tp+fn)
print("Sensitivity is ",end=" ")
print(sensitivity)

print ("specificity is ",end=" ")
print(specificity)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84        41
#            1       0.67      0.53      0.59        19
#
#     accuracy                           0.77        60
#    macro avg       0.73      0.70      0.71        60
# weighted avg       0.76      0.77      0.76        60
#
# AxesSubplot(0.125,0.125;0.62x0.755)
# Error is  0.23333333333333328
# Sensitivity is  0.5263157894736842
# specificity is  0.8780487804878049

# %%
from sklearn import metrics
fpr, tpr, thresh = metrics.roc_curve(Y_test,y_predict)
auc=metrics.auc(fpr, tpr)
plt.plot(fpr, tpr, label='ROC curve (area = %.4f)' %auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r', label='Random guess')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid()
plt.legend()
plt.show()

# %%
tn, fp, fn, tp = confusion_matrix(list(y_pred), list(Y_test), labels=[0, 1]).ravel()
print('True Positive', tp)

print('False Positive', fp)
# Out:
# True Positive 0
# False Positive 19

# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in c:\python310\lib\site-packages (3.3.3)
# Requirement already satisfied: scipy in c:\python310\lib\site-packages (from lightgbm) (1.8.0)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\python310\lib\site-packages (from lightgbm) (1.0.2)
# Requirement already satisfied: numpy in c:\python310\lib\site-packages (from lightgbm) (1.22.2)
# Requirement already satisfied: wheel in c:\python310\lib\site-packages (from lightgbm) (0.37.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python310\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\python310\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.0)
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Light Gradient Boosting

import lightgbm as lgb
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics

model = lgb.LGBMClassifier(learning_rate=0.09,max_depth=-5,random_state=42)
model.fit(X_train,Y_train,eval_set=[(X_test,Y_test),(X_train,Y_train)],
          verbose=20,eval_metric='logloss')
y_pred = model.predict(X_test)
print('Training accuracy {:.4f}'.format(model.score(X_train,Y_train)))
print('Testing accuracy {:.4f}'.format(model.score(X_test,Y_test)))

print(metrics.classification_report(Y_test, y_pred))
print(sns.heatmap(metrics.confusion_matrix(Y_test, y_pred),annot=True))

from sklearn.metrics import accuracy_score
acc=accuracy_score(Y_test, y_pred)
error=1-acc
print("Error is ",end=" ")
print(error)

from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(Y_test, y_pred).ravel()
specificity = tn / (tn+fp)
sensitivity=tp/(tp+fn)
print("Sensitivity is ",end=" ")
print(sensitivity)

print ("specificity is ",end=" ")
print(specificity)
# Out:
# c:\Python310\lib\site-packages\lightgbm\sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [20]	training's binary_logloss: 0.392391	valid_0's binary_logloss: 0.475444
# [40]	training's binary_logloss: 0.295902	valid_0's binary_logloss: 0.481574
# [60]	training's binary_logloss: 0.226696	valid_0's binary_logloss: 0.511813
# [80]	training's binary_logloss: 0.180716	valid_0's binary_logloss: 0.541134
# [100]	training's binary_logloss: 0.142943	valid_0's binary_logloss: 0.567426
# Training accuracy 0.9833
# Testing accuracy 0.7833
#               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.85        41
#            1       0.75      0.47      0.58        19
#
#     accuracy                           0.78        60
#    macro avg       0.77      0.70      0.72        60
# weighted avg       0.78      0.78      0.77        60
#
# AxesSubplot(0.125,0.125;0.62x0.755)
# Error is  0.21666666666666667
# Sensitivity is  0.47368421052631576
# specificity is  0.926829268292683

# %%
from sklearn import metrics
fpr, tpr, thresh = metrics.roc_curve(Y_test,y_pred)
auc=metrics.auc(fpr, tpr)
plt.plot(fpr, tpr, label='ROC curve (area = %.4f)' %auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r', label='Random guess')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid()
plt.legend()
plt.show()

# %%
tn, fp, fn, tp = confusion_matrix(list(y_pred), list(Y_test), labels=[0, 1]).ravel()
print('True Positive', tp)

print('False Positive', fp)
# Out:
# True Positive 9
# False Positive 10

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.7.1-py3-none-win_amd64.whl (89.1 MB)
#      ---------------------------------------- 89.1/89.1 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\python310\lib\site-packages (from xgboost) (1.22.2)
# Requirement already satisfied: scipy in c:\python310\lib\site-packages (from xgboost) (1.8.0)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.7.1
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#XGBoost

import xgboost as xgb

model = xgb.XGBClassifier()
model.fit(X_train, Y_train)
print(model)
expected_y  = Y_test
y_pred = model.predict(X_test)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, y_pred))

from sklearn.metrics import accuracy_score
acc=accuracy_score(Y_test, y_pred)
error=1-acc
print("Error is ",end=" ")
print(error)

from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(Y_test, y_pred).ravel()
specificity = tn / (tn+fp)
sensitivity=tp/(tp+fn)
print("Sensitivity is ",end=" ")
print(sensitivity)

print ("specificity is ",end=" ")
print(specificity)


from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(Y_test, y_pred)
print("AUC score is ",end=" ")
print(auc_score1)

from sklearn import metrics
fpr, tpr, thresh = metrics.roc_curve(Y_test,y_pred)
auc=metrics.auc(fpr, tpr)
plt.plot(fpr, tpr, label='ROC curve (area = %.4f)' %auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r', label='Random guess')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid()
plt.legend()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.81        41
#            1       0.60      0.47      0.53        19
#
#     accuracy                           0.73        60
#    macro avg       0.69      0.66      0.67        60
# weighted avg       0.72      0.73      0.72        60
#
# Error is  0.2666666666666667
# Sensitivity is  0.47368421052631576
# specificity is  0.8536585365853658
# AUC score is  0.6636713735558407

# %%
tn, fp, fn, tp = confusion_matrix(list(y_pred), list(Y_test), labels=[0, 1]).ravel()
print('True Positive', tp)

print('False Positive', fp)
# Out:
# True Positive 9
# False Positive 10

# %%
from sklearn import metrics

xgb_y_pred = model.predict(X_test)
xgb_cm = metrics.confusion_matrix(xgb_y_pred, Y_test)
sns.heatmap(log_reg_cm, annot=True, fmt='.2f',
xticklabels = ["Heart Not Failed","Heart Fail"] ,
yticklabels = ["Heart Not Failed","Heart Fail"] )
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('XGBoost')
# Out:
# Text(0.5, 1.0, 'XGBoost')
